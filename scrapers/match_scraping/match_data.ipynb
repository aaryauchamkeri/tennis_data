# %%
import pandas as pd

# %%
df = pd.read_csv('../match_data/atp_matches_2024.csv')

# %%
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
df
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                            2024-0339                      Brisbane    Hard
# 1                            2024-0339                      Brisbane    Hard
# 2                            2024-0339                      Brisbane    Hard
# 3                            2024-0339                      Brisbane    Hard
# 4                            2024-0339                      Brisbane    Hard
# ...                                ...                           ...     ...
# 3071  2024-M-DC-2024-WG2-PO-URU-MDA-01  Davis Cup WG2 PO: URU vs MDA    Clay
# 3072  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3073  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3074  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
# 3075  2024-M-DC-2024-WG2-PO-VIE-RSA-01  Davis Cup WG2 PO: VIE vs RSA    Hard
#
# ...

# %%
df = pd.read_csv('./matches1.csv')

# %%
df
# Out:
#       tourney_id matchId             tourney_name surface winner_id loser_id  \
# 0           9900   ms011               United Cup    Hard      fb98     hb71
# 1           9900   ms021               United Cup    Hard      fb98     m0fh
# 2           9900   ms031               United Cup    Hard      hb71     s0h2
# 3           9900   ms051               United Cup    Hard      m0fh     c0e9
# 4           9900   ms071               United Cup    Hard      hb71     hd68
# ...          ...     ...                      ...     ...       ...      ...
# 1480        1536   qs037  ATP Masters 1000 Madrid    Clay      cg80     v0am
# 1481        1536   qs043  ATP Masters 1000 Madrid    Clay      c0c8     sx91
# 1482        1536   qs041  ATP Masters 1000 Madrid    Clay      f510     rc04
# 1483        1536   qs053  ATP Masters 1000 Madrid    Clay      r0eb     da81
# 1484        1536   qs033  ATP Masters 1000 Madrid    Clay      ge33     d0lj
#
# ...

# %%
df[df['tourney_name'] == 'Australian Open']
# Out:
#      tourney_id matchId     tourney_name surface winner_id  best_of  minutes  \
# 190         580   ms001  Australian Open    Hard      s0ag        5      NaN
# 191         580   ms002  Australian Open    Hard      s0ag        5      NaN
# 192         580   ms003  Australian Open    Hard      z355        5      NaN
# 193         580   ms004  Australian Open    Hard      s0ag        5      NaN
# 194         580   ms005  Australian Open    Hard      s0s1        5      NaN
# ..          ...     ...              ...     ...       ...      ...      ...
# 420         580   qs089  Australian Open    Hard      o0a2        3      NaN
# 421         580   qs080  Australian Open    Hard      p0ct        3      NaN
# 422         580   qs122  Australian Open    Hard      s0gd        3      NaN
# 423         580   qs121  Australian Open    Hard      t0bw        3      NaN
# 424         580   qs105  Australian Open    Hard      v0dp        3      NaN
#
# ...

# %%
df = df.drop('score', axis = 1)

# %%
df
# Out:
#      tourney_id matchId tourney_name surface winner_id  best_of  minutes  \
# 0          9900   ms011   United Cup    Hard      fb98      3.0    138.0
# 1          9900   ms021   United Cup    Hard      fb98      2.0    111.0
# 2          9900   ms031   United Cup    Hard      hb71      2.0     58.0
# 3          9900   ms051   United Cup    Hard      m0fh      2.0     54.0
# 4          9900   ms071   United Cup    Hard      hb71      2.0    105.0
# ...         ...     ...          ...     ...       ...      ...      ...
# 1400        308   qs015       Munich    Clay      hd68      3.0    116.0
# 1401        308   qs009       Munich    Clay      s0h2      3.0    119.0
# 1402        308   qs011       Munich    Clay      v812      2.0     69.0
# 1403        308   qs013       Munich    Clay      d0lj      2.0     65.0
# 1404        308   qs008       Munich    Clay      gh92      2.0     92.0
#
#       w_ace  w_df  w_svpt  ...  w_bpFaced  l_ace  l_df  l_svpt  l_1stIn  \
# ...

# %%
df.corr(numeric_only=True)
# Out:
#             tourney_id   best_of   minutes     w_ace      w_df    w_svpt  \
# tourney_id    1.000000 -0.100723  0.060692 -0.038707  0.058805 -0.023173
# best_of      -0.100723  1.000000  0.027492  0.305944  0.139260  0.418853
# minutes       0.060692  0.027492  1.000000  0.201268  0.385644  0.929319
# w_ace        -0.038707  0.305944  0.201268  1.000000  0.188046  0.366626
# w_df          0.058805  0.139260  0.385644  0.188046  1.000000  0.459328
# w_svpt       -0.023173  0.418853  0.929319  0.366626  0.459328  1.000000
# w_1stIn      -0.037917  0.422332  0.875001  0.370776  0.343930  0.947933
# w_1stWon     -0.047311  0.466561  0.821977  0.502731  0.352641  0.910715
# w_2ndWon      0.002494  0.324580  0.634782  0.237752  0.370445  0.708087
# w_SvGms       0.136789 -0.581587  0.910268 -0.035180  0.076515  0.151075
# w_bpSaved     0.017298  0.124719  0.475410  0.050985  0.318390  0.589956
# w_bpFaced     0.016753  0.144054  0.601459  0.019827  0.371288  0.673266
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['tourney_id', 'matchId', 'tourney_name', 'surface', 'winner_id',
#        'best_of', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced'],
#       dtype='object')

# %%
hubert = df.loc[(df['winner_id'] == 'a0e2') | (df['loser_id'] == 'a0e2')]

# %%
hubert
# Out:
#       tourney_id matchId                   tourney_name surface winner_id  \
# 196          580   ms006                Australian Open    Hard      d643
# 198          580   ms013                Australian Open    Hard      a0e2
# 210          580   ms027                Australian Open    Hard      a0e2
# 234          580   ms055                Australian Open    Hard      a0e2
# 276          580   ms111                Australian Open    Hard      a0e2
# 507          407   ms001                      Rotterdam    Hard      a0e2
# 508          407   ms002                      Rotterdam    Hard      a0e2
# 510          407   ms004                      Rotterdam    Hard      a0e2
# 514          407   ms008                      Rotterdam    Hard      a0e2
# 527          407   ms016                      Rotterdam    Hard      a0e2
# 667          451   ms004                           Doha    Hard      l0bv
# 671          451   ms008                           Doha    Hard      a0e2
# ...

# %%
total = hubert[['best_of','minutes','w_ace']]

# %%
total.corr()
# Out:
#           best_of   minutes     w_ace
# best_of  1.000000       NaN  0.593624
# minutes       NaN  1.000000 -0.056414
# w_ace    0.593624 -0.056414  1.000000

# %%
hubert
# Out:
#       tourney_id matchId                   tourney_name surface winner_id  \
# 196          580   ms006                Australian Open    Hard      d643
# 198          580   ms013                Australian Open    Hard      a0e2
# 210          580   ms027                Australian Open    Hard      a0e2
# 234          580   ms055                Australian Open    Hard      a0e2
# 276          580   ms111                Australian Open    Hard      a0e2
# 507          407   ms001                      Rotterdam    Hard      a0e2
# 508          407   ms002                      Rotterdam    Hard      a0e2
# 510          407   ms004                      Rotterdam    Hard      a0e2
# 514          407   ms008                      Rotterdam    Hard      a0e2
# 527          407   ms016                      Rotterdam    Hard      a0e2
# 667          451   ms004                           Doha    Hard      l0bv
# 671          451   ms008                           Doha    Hard      a0e2
# ...

# %%
hubert[hubert['winner_id'] == 'a0e2']['w_ace'].sum()
# Out:
# 93
